# %% [markdown]
# <a href="https://colab.research.google.com/github/8786park3-hue/test/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# sample_data
